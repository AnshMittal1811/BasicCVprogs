# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshMittal1811/BasicCVprogs/blob/master/DisplayingNumbers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install ipython-autotime
# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=6e1b4d956e67cd21a26f4b221b1a5a33cd90d1a0ce1b9552c8b103226b821447
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1

# %%
cd 'drive/My Drive/Data/DisplayNumbers'
# Out:
# /content/drive/My Drive/Data/DisplayNumbers
# time: 3.84 ms

# %%
ls
# Out:
# Img1.png  Img2.png
# time: 3.93 s

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow
import imutils
# Out:
# time: 13.5 ms

# %%
import glob
images = glob.glob('*.png')
# Out:
# time: 2.3 ms

# %%
images
# Out:
# ['Img2.png', 'Img1.png']
# time: 3.02 ms

# %%
for i in range(len(images)):
    img = cv.imread(images[i])
    kernel = np.array([[-1,-1,-1], 
                       [-1,9,-1], 
                       [-1,-1,-1]])
    blur = cv.GaussianBlur(img,(5,5),0)
    img = cv.filter2D(img, -1, kernel)
    print(images[i])
    cv2_imshow(img)
    print('-'*20)
# Out:
# Img2.png
# <PIL.Image.Image image mode=RGB size=470x557 at 0x7F4EA6E85550>
# --------------------
# Img1.png
# <PIL.Image.Image image mode=RGB size=697x297 at 0x7F4EA6E854A8>
# --------------------
# time: 233 ms
